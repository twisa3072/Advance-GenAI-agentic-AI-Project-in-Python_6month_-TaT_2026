# %% [markdown]
# # Math Function

# %%
x = sqrt(144) # Math function is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(144) # Math function is not defined
#
# NameError: name 'sqrt' is not defined

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math # Math function is defined
math.sqrt(144)
# Out:
# 12.0

# %%
round(math.sqrt(144)) # Round off value
# Out:
# 12

# %%
x = round(math.sqrt(144))
x
# Out:
# 12

# %%
math.floor(6.5)
# Out:
# 6

# %%
math.ceil(9.2)
# Out:
# 10

# %%
pow(4,2)
# Out:
# 16

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi=3.18 # in python no constants....only variables
pi
# Out:
# 3.18

# %%
# help()  -- if you wanted to know any information python then use -- quit

# %%
m.sqrt(144) #not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 m.sqrt(144) #not defined
#
# NameError: name 'm' is not defined

# %%
math.sqrt(144)
# Out:
# 12.0

# %%
import math as m

# %%
m.sqrt(144)
# Out:
# 12.0

# %% [markdown]
#  import math as m:
#  m.sqrt()---> use only one function
# // from math import*:
# we can use all inbuilt functions

# %%
from math import sqrt, pow # math has many function if you want to import specific function then use import
print(pow(3,3))
print(m.sqrt(100))
# Out:
# 27.0
# 10.0

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# # Input()

# %%
input()
# Out:
# 'hi'

# %%
input()
input()
# Out:
# 'Twisa'

# %%
x = input()
y = input()
z = x + y # it is not 45 it is 4 & 5 without being spaced
print(z)
# Out:
# 45

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x = int(input()) # convert string into integer
y = int(input())
z = x + y
print(z)
# Out:
# 9

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1 = input('Enter the 1st number') #whenever we work in input function it always give string 
y1 = input('Enter the 2nd number') # it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# 3050

# %%
x1 = int(input('Enter the 1st number')) #whenever we work in input function it always gives string 
y1 = int(input('Enter the 2nd number')) # it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# 80

# %%
x2 = input('Enter user_name: ') #whenevery you works in input function it always give you string 
y2 = input('Enter password: ') # it wont understand as arithmetic operator
z2 = x2 + y2
print(z2)
# Out:
# TwisaDhoble

# %%
st = input('enter a string')
print(st)
#print(type(ch))
# Out:
# Good Afternoon

# %%
st = input('enter a string')[0]
print(st)
# Out:
# G

# %%
st = input('enter a string')[0:2]
print(st)
# Out:
# Go

# %%
st = input('enter a string')[9:13]
print(st)
# Out:
# rnoo
