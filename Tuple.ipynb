# %% [markdown]
# # Tuple Creation

# %%
# Empty Tuple

# %%
tup1=()
tup1
# Out:
# ()

# %%
# Tuple of integers

# %%
tup2=(10,40,80,120)
tup2
# Out:
# (10, 40, 80, 120)

# %% [markdown]
# Tuple of Float

# %%
tup3=(11.87,40.57,80.32,120.85)
tup3
# Out:
# (11.87, 40.57, 80.32, 120.85)

# %% [markdown]
# Tuple of Strings

# %%
tup4=('one','two', 'three','four')
tup4
# Out:
# ('one', 'two', 'three', 'four')

# %% [markdown]
# Nested Tuples

# %%
tup5=('Aisha', 20, (40,80), (140,90))
tup5
# Out:
# ('Aisha', 20, (40, 80), (140, 90))

# %% [markdown]
# Tuple of Mixed Datatypes

# %%
tup6=(100, 'Aisha', 25.825)
tup6
# Out:
# (100, 'Aisha', 25.825)

# %%
tup7=('Aisha', 20, (40,80), (140,90),{'Ramchandra', 'Gaurav'}, (88,44,22))
tup7
# Out:
# ('Aisha', 20, (40, 80), (140, 90), {'Gaurav', 'Ramchandra'}, (88, 44, 22))

# %%
len(tup7)
# Out:
# 6

# %% [markdown]
# Tuple Indexing
# Retrieve 1st element of the tuple

# %%
tup2[0]
# Out:
# 10

# %%
tup4[0]
# Out:
# 'one'

# %%
# Nested indexing access the 1st character of the 1st tuple element

# %%
tup4[0][0]
# Out:
# 'o'

# %%
tup5[0][0]
# Out:
# 'A'

# %%
tup4[-1] # last item of tuple
# Out:
# 'four'

# %%
tup5[-1] # last item of tuple
# Out:
# (140, 90)

# %%
tup6[-1] # last item of tuple
# Out:
# 25.825

# %% [markdown]
# Tuple Slicing

# %%
mytuple=('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')

# %%
len(mytuple)
# Out:
# 10

# %%
mytuple[0:4]
# Out:
# ('one', 'two', 'three', 'four')

# %%
mytuple[4:10]
# Out:
# ('five', 'six', 'seven', 'eight', 'nine', 'ten')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[-3]
# Out:
# 'eight'

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')

# %% [markdown]
# Remove & change items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')

# %%
del mytuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mytuple[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #deleting enitre tuple object is possible

# %%
del mytuple

# %% [markdown]
# Loop through a tuple

# %%
mytuple=('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight
# nine
# ten

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')
# (8, 'nine')
# (9, 'ten')

# %% [markdown]
# Tuple Membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')

# %% [markdown]
# checking if one and eleven exists in the list

# %%
'one' in mytuple
# Out:
# True

# %%
'eleven' in mytuple
# Out:
# False

# %% [markdown]
# chceking if three exists in my list

# %%
if 'three' in mytuple:
    print('three is present in the tuple')
else:
    print('three is not there in the tuple')
# Out:
# three is present in the tuple

# %% [markdown]
# checking if eleven exists in my list

# %%
if 'eleven' in mytuple:
    print('eleven is present in the tuple')
else:
    print('eleven is not there in the tuple')
# Out:
# eleven is not there in the tuple

# %% [markdown]
# Index Position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten')

# %% [markdown]
# index of first element is equal to 'one'

# %%
mytuple.index('one')
# Out:
# 0

# %%
mytuple.index('five')
# Out:
# 4

# %%
mytuple1=('one', 'two', 'three', 'four', 'five', 'one', 'one', 'two', 'three', 'four')
mytuple1
# Out:
# ('one', 'two', 'three', 'four', 'five', 'one', 'one', 'two', 'three', 'four')

# %%
mytuple1.index('one')
# Out:
# 0

# %%
mytuple1.index('five')
# Out:
# 4

# %% [markdown]
# Sorting

# %%
mytuple2= (52,68,88,25,17,1,6,98)
mytuple2
# Out:
# (52, 68, 88, 25, 17, 1, 6, 98)

# %% [markdown]
# returns a new sorted list and does not change original tuple

# %%
sorted(mytuple2) #sorted in ascending order
# Out:
# [1, 6, 17, 25, 52, 68, 88, 98]

# %%
sorted(mytuple2, reverse=True) #sorted in descending order
# Out:
# [98, 88, 68, 52, 25, 17, 6, 1]
