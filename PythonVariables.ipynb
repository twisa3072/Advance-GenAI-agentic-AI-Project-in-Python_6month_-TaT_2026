# %% [markdown]
# # Variable Declaration In Python (Variable = object = identifier)

# %%
nit = 1050
nit
# Out:
# 1050

# %%
1050 = nit
# Out:
#   Cell In[26], line 1
#     1050 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit = 50 # Cannot start with number
1nit
# Out:
#   Cell In[3], line 1
#     1nit = 50
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 50 # Can end with number
nit1
# Out:
# 50

# %%
nit = 45 # Variables are case sensitive
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 nit = 45
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit@ = 45 # No special Character
# Out:
#   Cell In[7], line 1
#     nit@ = 45
#          ^
# SyntaxError: invalid syntax

# %%
nit_ = 30 # only underscore is allowed
nit_
# Out:
# 30

# %%
nit$ = 1 # No special characters
nit$
# Out:
#   Cell In[10], line 1
#     nit$ = 1
#        ^
# SyntaxError: invalid syntax

# %%
a= 35 # Variables are case sensitive (lowercase or uppercase)
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 a= 35
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
_nit= 70
_nit
# Out:
# 70

# %%
_ # It defines previous values
# Out:
# 70

# %%
_nit

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist) #length
# Out:
# 35

# %%
if=90 # keywords are not defined as variables
    if
# Out:
#   Cell In[19], line 1
#     if=90
#       ^
# SyntaxError: invalid syntax

# %%
else = 45
else
# Out:
#   Cell In[20], line 1
#     else = 45
#     ^
# SyntaxError: invalid syntax

# %%
lambda = 50
lambda
# Out:
#   Cell In[21], line 1
#     lambda = 50
#            ^
# SyntaxError: invalid syntax

# %%
For = 50 # valid b'cuz Capital F is valid
For
# Out:
# 50

# %%
true = 86
true
# Out:
# 86

# %%
a = true
a
# Out:
# 86

# %% [markdown]
# # Storing and printing a value

# %%
x = 3072
print(x)
# Out:
# 3072

# %% [markdown]
# # Using Variable in Expressions

# %%
a = 45
b = 55
result = a+b
print(result)
# Out:
# 100

# %% [markdown]
# # Changing the value of Variable

# %%
Score = 150
print(Score)

Score = 200
print(Score)
# Out:
# 150
# 200

# %% [markdown]
# # Concatenating Strings

# %%
first_name = "Twisa"
middle_name = "Mahendra"
last_name = "Dhoble"
full_name = first_name + " " + middle_name + " " + last_name
print(full_name)
# Out:
# Twisa Mahendra Dhoble

# %% [markdown]
# # Using Variables in Calculation

# %%
length = 10
width = 5
print(area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 length = 10
#       2 width = 5
# ----> 3 print(area)
#
# NameError: name 'area' is not defined

# %% [markdown]
# # Variables.py

# %%
first_name = 'Twisa'
last_name = 'Dhoble'
country = 'India'
city = 'Chandrapur'
age = 24
is_married = False
skills = ['Java','MS Office','Python']
person_info = { 'firstname' : 'Raffaella',
                'lastname':'Petrini',
                 'Country' : 'Rome',
                 'City' : 'Vatican City'}

#Printing the values stored in the variables

print('First name:',first_name)
print('First name length:', len(first_name))
print('Last name:' , last_name)
print('Last name length:',len(last_name))
print('Country:',country)
print('City:',city)
print('Age:',age)
print('Married:',is_married)
print('Skills:',skills)
print('Person information:',person_info)

#Declaring multiple variables in one line

first_name , last_name ,country , age , is_married = 'Twisa' , 'Dhoble' , 'Vatican City' , 22 ,False

print(first_name,last_name,country,age,is_married)
print('First name:',first_name)
print('Last name:',last_name)
print('Country:',country)
print('Age:',age)
print('Married:',is_married)
# Out:
# First name: Twisa
# First name length: 5
# Last name: Dhoble
# Last name length: 6
# Country: India
# City: Chandrapur
# Age: 24
# Married: False
# Skills: ['Java', 'MS Office', 'Python']
# Person information: {'firstname': 'Raffaella', 'lastname': 'Petrini', 'Country': 'Rome', 'City': 'Vatican City'}
# Twisa Dhoble Vatican City 22 False
# First name: Twisa
# Last name: Dhoble
# Country: Vatican City
# Age: 22
# Married: False
