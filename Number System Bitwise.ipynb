# %%
35
# Out:
# 35

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(20)
# Out:
# '0b10100'

# %%
int(0b100011)
# Out:
# 35

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
print(0xa)
print(0xb)
print(0xc)
print(0xd)
print(0xe)
print(0xf)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
print(0xg)
# Out:
#   Cell In[9], line 1
#     print(0xg)
#            ^
# SyntaxError: invalid hexadecimal literal

# %% [markdown]
# # Bitwise Operator (Complement ~)

# %%
a = 6

# %%
a
# Out:
# 6

# %%
-a
# Out:
# -6

# %%
~6
# Out:
# -7

# %%
12
# Out:
# 12

# %%
~12
# Out:
# -13

# %% [markdown]
#  # Bitwise
# # And

# %%
14 & 15
# Out:
# 14

# %%
print(bin(14))
print(bin(20))
# Out:
# 0b1110
# 0b10100

# %%
14 & 20
# Out:
# 4

# %% [markdown]
# # OR

# %%
14 | 15
# Out:
# 15

# %% [markdown]
# # XOR

# %%
14 ^ 15
# Out:
# 1

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25 ^ 30
# Out:
# 7

# %% [markdown]
# # Left Shift <<

# %%
12 << 1
# Out:
# 24

# %%
12 << 2
# Out:
# 48

# %%
bin(25)
# Out:
# '0b11001'

# %%
25 << 1
# Out:
# 50

# %%
25 << 2
# Out:
# 100

# %% [markdown]
# # Right Shift >>
# we loose the bit

# %%
14 >> 1
# Out:
# 7

# %%
15 >> 3
# Out:
# 1

# %%
25 >> 2
# Out:
# 6
