# %%
welcome to nareshit & request to everyone subscribe naresh it youtube, insta
# Out:
#   Cell In[1], line 1
#     welcome to nareshit & request to everyone subscribe naresh it youtube, insta
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to nareshit & request to everyone subscribe naresh it youtube, insta'
# Out:
# 'welcome to nareshit & request to everyone subscribe naresh it youtube, insta'

# %%
"welcome to nareshit & request to everyone subscribe naresh it youtube, insta"
# Out:
# 'welcome to nareshit & request to everyone subscribe naresh it youtube, insta'

# %%
'''welcome to nareshit & request to everyone subscribe naresh it youtube, insta'''
# Out:
# 'welcome to nareshit & request to everyone subscribe naresh it youtube, insta'

# %%
"welcome to nareshit 
request to everyone subscribe
naresh it youtube, insta"
# Out:
#   Cell In[5], line 1
#     "welcome to nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome to nareshit 
request to everyone subscribe
naresh it youtube, insta'''
# Out:
# 'welcome to nareshit \nrequest to everyone subscribe\nnaresh it youtube, insta'

# %%
s = 'python'
s
# Out:
# 'python'

# %% [markdown]
# #  String Indexing (Forward & Backward)

# %%
s1 = 'Welcome'
s1
# Out:
# 'Welcome'

# %%
s1[3]
# Out:
# 'c'

# %%
s1[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s1[9]
#
# IndexError: string index out of range

# %%
s1
# Out:
# 'Welcome'

# %%
s1[-5]
# Out:
# 'l'

# %% [markdown]
# # String Slicing (Forward & Backward)

# %%
s1
# Out:
# 'Welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1[6]
# Out:
# 'e'

# %%
s1[-2]
# Out:
# 'm'

# %%
s1[:]
# Out:
# 'Welcome'

# %%
s2= 'nareshtechnology'
s2
# Out:
# 'nareshtechnology'

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
len(s2)
# Out:
# 16

# %%
s2[0:]
# Out:
# 'nareshtechnology'

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
s2[:6]
# Out:
# 'naresh'

# %%
s2
# Out:
# 'nareshtechnology'

# %%
s2[:3]
# Out:
# 'nar'

# %%
s3 = 'Welcometeam'
s3
# Out:
# 'Welcometeam'

# %%
s3[1:5]
# Out:
# 'elco'

# %%
s3[1:8:3]
# Out:
# 'eot'

# %%
s3
# Out:
# 'Welcometeam'

# %%
s3[::1]
# Out:
# 'Welcometeam'

# %%
s3[::2]
# Out:
# 'Wloeem'

# %%
s3[::3]
# Out:
# 'Wcea'

# %%
s3
# Out:
# 'Welcometeam'

# %%
s3[::-1]
# Out:
# 'maetemocleW'

# %%
s3[::-2]
# Out:
# 'meeolW'

# %%
s3[::-3]
# Out:
# 'mtoe'
