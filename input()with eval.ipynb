# %% [markdown]
# #  Input function with eval

# %%
exp = input('Enter a value')
print(exp)
# Out:
# 5+3-2

# %%
exp1 = int(input('Enter a value')) #Value Error
print(exp1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 exp1 = int(input('Enter a value'))
#       2 print(exp1)
#
# ValueError: invalid literal for int() with base 10: '5+3-2'

# %%
exp1 = eval(input('Enter a value')) #Input functions with eval
print(exp1)
# Out:
# 6
