# %% [markdown]
# # Python Type Casting
# # * car()--car function without argument
# # * asian_car('tata','to')--car function with 2 argument | type of argument string
# # * german_car('audi','bmw','ferari','w')--germ car with 4 argument
# # *today in this code define 3 function ends with ()

# %%
int(2.3)
# Out:
# 2

# %%
int(2.5,3.8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int(2.5,3.8)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other datatype to float

# %%
float(20)
# Out:
# 20.0

# %%
float(False)
# Out:
# 0.0

# %%
float(True)
# Out:
# 1.0

# %%
float(20.0)
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # All other datatypes to boolean

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2+3j)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool('zero')
# Out:
# True

# %%
val1 = 20
val1
# Out:
# 20

# %%
import sys
sys.getsizeof(val1)
# Out:
# 28

# %%
val2=[20,30,50]
val2
# Out:
# [20, 30, 50]

# %%
import sys
sys.getsizeof(val2)
# Out:
# 88

# %% [markdown]
# # Python Tutorial

# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %% [markdown]
# # Keywords

# %% [markdown]
# Keywords are the reserve words in Python and can't be used as an identifier

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # Identifiers

# %%
1var = 10 # cannot start with digit
# Out:
#   Cell In[37], line 1
#     1var = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35
# Out:
#   Cell In[38], line 1
#     val2@ = 35
#           ^
# SyntaxError: invalid syntax

# %%
import = 182 #keywords can't be used as identifiers
# Out:
#   Cell In[39], line 1
#     import = 182
#            ^
# SyntaxError: invalid syntax

# %%
val2 = 100 #Correct way of defining an identifier
val2 # (Identifiers can be a combination a letters in lowercase or uppercase)
# Out:
# 100

# %% [markdown]
# # Comments in Python

# %%
val1 = 20 #single line comment

# %%
# multiple 
# line 
# comment
val1 = 20

# %%
"""
Multiple 
line 
comment
"""
val1 = 20

# %% [markdown]
# # Statements

# %% [markdown]
# Instructions that python interpreter can execute

# %%
p=20 #creates an integer wobject with value 20 and assigns the variable p to p
q=20 #Create new reference q which will point to value 20 , p & q will be point
r=q #variable r will also point to the same location where p & q are point in point
p , type(p),hex(id(p)) #variable P is pointing to memory loaction'0x7ffafd0ea608'
# Out:
# (20, int, '0x7ff859bd5608')

# %%
q , type(q),hex(id(q))
# Out:
# (20, int, '0x7ff859bd5608')

# %%
r , type(r) , hex(id(r))
# Out:
# (20, int, '0x7ff859bd5608')

# %%
p = 28
p = p + 12 #Variable Overfitting
p
# Out:
# 40

# %% [markdown]
# # Variable Assignment

# %%
intvar = 60 #Integer Variable
floatvar = 8.25 #Float Variable
strvar = "Python Language" # String Variable

print(intvar)
print(floatvar)
print(strvar)
# Out:
# 60
# 8.25
# Python Language

# %%
p1 = p2 = p3 = p4 = 92 #All variables pointing to same value
print(p1,p2,p3,p4)
# Out:
# 92 92 92 92

# %% [markdown]
# # Datatypes
# # Numeric

# %%
val1 = 10 #Integer data type
print(val1) 
print(type(val1)) # type of object
print(sys.getsizeof(val1)) #size of integer object in bytes
print(val1 , "is Integer?" , isinstance(val1,int)) # val1 is an instance of int
# Out:
# 10
# <class 'int'>
# 28
# 10 is Integer? True

# %%
val2 = 92.78 #Float Data Type
print(val2)
print(type(val2)) #type of object
print(sys.getsizeof(val2)) #size of float object in bytes
print(val2 , "is float?" , isinstance(val2,float)) #val2 is an instance of float
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78 is float? True

# %%
val3 = 25+10j #Complex Data Type
print(val3)
print(type(val3)) #type of object
print(sys.getsizeof(val3)) #size of complex object in byte
print(val3 , "is Complex?" , isinstance(val3,complex)) #val3 is an instance of complex
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j) is Complex? True

# %%
sys.getsizeof(int()) #size of integer object in bytes
# Out:
# 28

# %%
sys.getsizeof(float()) # size of float in bytes
# Out:
# 24

# %%
sys.getsizeof(complex()) # size of complex in byte
# Out:
# 32

# %% [markdown]
# # Boolean

# %% [markdown]
# Boolean data type can have only two possible values true or false

# %%
bool1 = True
bool1
# Out:
# True

# %%
bool2 = False
bool2
# Out:
# False

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
print(type(bool2))
# Out:
# <class 'bool'>

# %%
isinstance(bool1,bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # Strings

# %% [markdown]
# # String Creation

# %%
str1 = "Hello World"
print(str1)
# Out:
# Hello World

# %%
mystr = 'Hello Everyone' #Define string using single quotes
print(mystr)
# Out:
# Hello Everyone

# %%
mystr = "Hello Everyone" #Define string using double quotes
print(mystr)
# Out:
# Hello Everyone

# %%
mystr = """Hello 
           Everyone""" #Define string using triple quotes
print(mystr)
# Out:
# Hello
#            Everyone

# %%
mystr = ('Happy'
        'Sunday'
        'Everyone')
print(mystr)
# Out:
# HappySundayEveryone

# %%
mystr2 = 'Wooho'
mystr2 = mystr2*5
mystr2
# Out:
# 'WoohoWoohoWoohoWoohoWooho'

# %%
len(mystr2) #Length of the string
# Out:
# 25

# %% [markdown]
# # String Indexing

# %%
str1
# Out:
# 'Hello World'

# %%
str1[0] # 1st character in string
# Out:
# 'H'

# %%
str1[len(str1)-1] # last character in string length function
# Out:
# 'd'

# %%
str1[-1] #last character in string
# Out:
# 'd'

# %%
str1[6]
# Out:
# 'W'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# # String Slicing

# %%
str1[0:5] # Fetch all characters from 0 to 5
# Out:
# 'Hello'

# %%
str1[6:12] #Retrieve all characters between 6 to 12
# Out:
# 'World'

# %%
str1[-4:]
# Out:
# 'orld'

# %%
str1[-6:]
# Out:
# ' World'

# %%
str1[:4]
# Out:
# 'Hell'

# %%
str1[:6]
# Out:
# 'Hello '

# %% [markdown]
# # Update and delete string

# %%
str1
# Out:
# 'Hello World'

# %%
#Strings are immutable which means elemnts of a string cannot be changes 
str1[0:5] = 'HOOLA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 2
#       1 #Strings are immutable which means elemnts of a string cannot be changes
# ----> 2 str1[0:5] = 'HOOLA'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 # Delete the string
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 2
#       1 del str1 # Delete the string
# ----> 2 print(str1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# # String Concatenation

# %%
#String concatenation
s1 = "Hello"
s2 = "Gaurav"
s3 = s1 + s2
print(s3)
# Out:
# HelloGaurav
