# %%
import os
import nltk
nltk.download()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import nltk
#       3 nltk.download()
#
# ModuleNotFoundError: No module named 'nltk'
