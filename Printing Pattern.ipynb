# %%
for i in range(1,5):
    if i<=5:
        print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for j in range(4):
    print('#')
# Out:
# #
# #
# #
# #

# %%
for j in range(4):
    print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for j in range(4):
    print('#', end=" ")
# Out:
# # # # #

# %%
for j in range(4):
    print('#', end=" ")

for j in range(4):
    print('#', end=" ")
# Out:
# # # # # # # # #

# %%
for j in range(4):
    print('#', end=" ")
print()
for j in range(4):
    print('#', end=" ")
print()
# Out:
# # # # #
# # # # #

# %%
for j in range(4):
    print('#', end=" ")
print()
for j in range(4):
    print('#', end=" ")
print()
for j in range(4):
    print('#', end=" ")
print()
for j in range(4):
    print('#', end=" ")
print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for k in range(6):
    print('#', end=" ")
print()
for k in range(6):
    print('#', end=" ")
print()
for k in range(6):
    print('#', end=" ")
print()
for k in range(6):
    print('#', end=" ")
print()
for k in range(6):
    print('#', end=" ")
print()
for k in range(6):
    print('#', end=" ")
print()
# Out:
# # # # # # #
# # # # # # #
# # # # # # #
# # # # # # #
# # # # # # #
# # # # # # #

# %%
for i in range(1,5):
    
   for j in range(4):
      if i>j:
        print("#")
print()
# Out:
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #

# %%
for i in range(1,5):
    print("# "*i)
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(1,5):
    for j in range(4):
        if i>j:
            print("#",end=" ")
    print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(4):
    for j in range(i+1):
        print('#',end=" ")
    print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(4):
    for j in range(4-i):
        print('#',end=" ")
    print()
# Out:
# # # # #
# # # #
# # #
# #

# %%
for i in range(1,5):
    print(" # "*(5-i))
# Out:
#  #  #  #  #
#  #  #  #
#  #  #
#  #

# %%
for i in range(6):
    for j in range(6):
        if i<j:
            print("#", end=" ")
    print()
# Out:
# # # # # #
# # # # #
# # # #
# # #
# #
